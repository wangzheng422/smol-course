# %% [markdown]
# <a href="https://colab.research.google.com/github/wangzheng422/smol-course/blob/wzh/6_synthetic_datasets/notebooks/instruction_sft_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generate a dataset for instruction tuning
#
# This notebook will guide you through the process of generating a dataset for instruction tuning. We'll use the `distilabel` package to generate a dataset for instruction tuning.
#
# So let's dig in to some instruction tuning datasets.
#
# <div style='background-color: lightblue; padding: 10px; border-radius: 5px; margin-bottom: 20px; color:black'>
#     <h2 style='margin: 0;color:blue'>Exercise: Generate a dataset for instruction tuning</h2>
#     <p>Now that you've seen how to generate a dataset for instruction tuning, try generating a dataset for instruction tuning.</p>
#     <p><b>Difficulty Levels</b></p>
#     <p>🐢 Generate an instruction tuning dataset</p>
#     <p>🐕 Generate a dataset for instruction tuning with seed data</p>
#     <p>🦁 Generate a dataset for instruction tuning with seed data and with instruction evolution</p>
# </div>

# %% [markdown]
# ## Install dependencies
#
# Instead of transformers, you can also install `vllm` or `hf-inference-endpoints`.

# %%
# !pip install "distilabel[hf-transformers,outlines,instructor]"
# Out:
# Requirement already satisfied: distilabel[hf-transformers,instructor,outlines] in /usr/local/lib/python3.11/dist-packages (1.5.3)
# Requirement already satisfied: datasets>=2.16.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-transformers,instructor,outlines]) (3.6.0)
# Requirement already satisfied: httpx>=0.25.2 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-transformers,instructor,outlines]) (0.28.1)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-transformers,instructor,outlines]) (3.1.6)
# Requirement already satisfied: multiprocess>=0.70 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-transformers,instructor,outlines]) (0.70.15)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-transformers,instructor,outlines]) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-transformers,instructor,outlines]) (3.5)
# Requirement already satisfied: orjson>=3.10.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-transformers,instructor,outlines]) (3.10.18)
# Requirement already satisfied: portalocker>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-transformers,instructor,outlines]) (3.2.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-transformers,instructor,outlines]) (2.11.7)
# Requirement already satisfied: rich>=13.5.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-transformers,instructor,outlines]) (13.9.4)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-transformers,instructor,outlines]) (1.15.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-transformers,instructor,outlines]) (75.2.0)
# Requirement already satisfied: tblib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-transformers,instructor,outlines]) (3.1.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-transformers,instructor,outlines]) (0.16.0)
# Requirement already satisfied: universal-pathlib>=0.2.2 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-transformers,instructor,outlines]) (0.2.6)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-transformers,instructor,outlines]) (2.6.0+cu124)
# Requirement already satisfied: transformers>=4.34.1 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-transformers,instructor,outlines]) (4.52.4)
# Requirement already satisfied: instructor>=1.2.3 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-transformers,instructor,outlines]) (1.9.0)
# Requirement already satisfied: numba>=0.54.0 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-transformers,instructor,outlines]) (0.60.0)
# Requirement already satisfied: outlines>=0.0.40 in /usr/local/lib/python3.11/dist-packages (from distilabel[hf-transformers,instructor,outlines]) (1.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (3.5.0)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (0.33.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (6.0.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->distilabel[hf-transformers,instructor,outlines]) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->distilabel[hf-transformers,instructor,outlines]) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->distilabel[hf-transformers,instructor,outlines]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->distilabel[hf-transformers,instructor,outlines]) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.25.2->distilabel[hf-transformers,instructor,outlines]) (0.16.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (3.11.15)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (0.16)
# Requirement already satisfied: jiter<0.11,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (0.10.0)
# Requirement already satisfied: mkdocs-material>=9.5.49 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (9.6.14)
# Requirement already satisfied: mkdocs>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (1.6.1)
# Requirement already satisfied: openai<2.0.0,>=1.70.0 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (1.91.0)
# Requirement already satisfied: pre-commit>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (4.2.0)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (2.33.2)
# Requirement already satisfied: tenacity<10.0.0,>=8.2.3 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (8.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=3.1.2->distilabel[hf-transformers,instructor,outlines]) (3.0.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.54.0->distilabel[hf-transformers,instructor,outlines]) (0.43.0)
# Requirement already satisfied: interegular in /usr/local/lib/python3.11/dist-packages (from outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (0.3.3)
# Requirement already satisfied: lark in /usr/local/lib/python3.11/dist-packages (from outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (1.2.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (3.1.1)
# Requirement already satisfied: diskcache in /usr/local/lib/python3.11/dist-packages (from outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (5.6.3)
# Requirement already satisfied: referencing in /usr/local/lib/python3.11/dist-packages (from outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (0.36.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (4.24.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (11.2.1)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (4.14.0)
# Requirement already satisfied: iso3166 in /usr/local/lib/python3.11/dist-packages (from outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (2.1.1)
# Requirement already satisfied: airportsdata in /usr/local/lib/python3.11/dist-packages (from outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (20250622)
# Requirement already satisfied: outlines_core==0.1.26 in /usr/local/lib/python3.11/dist-packages (from outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (0.1.26)
# Requirement already satisfied: genson in /usr/local/lib/python3.11/dist-packages (from outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->distilabel[hf-transformers,instructor,outlines]) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->distilabel[hf-transformers,instructor,outlines]) (0.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.5.0->distilabel[hf-transformers,instructor,outlines]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.5.0->distilabel[hf-transformers,instructor,outlines]) (2.19.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.34.1->distilabel[hf-transformers,instructor,outlines]) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.34.1->distilabel[hf-transformers,instructor,outlines]) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.34.1->distilabel[hf-transformers,instructor,outlines]) (0.5.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->distilabel[hf-transformers,instructor,outlines]) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->distilabel[hf-transformers,instructor,outlines]) (1.5.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (1.20.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (1.1.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.5.0->distilabel[hf-transformers,instructor,outlines]) (0.1.2)
# Requirement already satisfied: ghp-import>=1.0 in /usr/local/lib/python3.11/dist-packages (from mkdocs>=1.6.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (2.1.0)
# Requirement already satisfied: markdown>=3.3.6 in /usr/local/lib/python3.11/dist-packages (from mkdocs>=1.6.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (3.8.2)
# Requirement already satisfied: mergedeep>=1.3.4 in /usr/local/lib/python3.11/dist-packages (from mkdocs>=1.6.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (1.3.4)
# Requirement already satisfied: mkdocs-get-deps>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from mkdocs>=1.6.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (0.2.0)
# Requirement already satisfied: pathspec>=0.11.1 in /usr/local/lib/python3.11/dist-packages (from mkdocs>=1.6.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (0.12.1)
# Requirement already satisfied: pyyaml-env-tag>=0.1 in /usr/local/lib/python3.11/dist-packages (from mkdocs>=1.6.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (1.1)
# Requirement already satisfied: watchdog>=2.0 in /usr/local/lib/python3.11/dist-packages (from mkdocs>=1.6.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (6.0.0)
# Requirement already satisfied: babel~=2.10 in /usr/local/lib/python3.11/dist-packages (from mkdocs-material>=9.5.49->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (2.17.0)
# Requirement already satisfied: backrefs~=5.7.post1 in /usr/local/lib/python3.11/dist-packages (from mkdocs-material>=9.5.49->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (5.9)
# Requirement already satisfied: colorama~=0.4 in /usr/local/lib/python3.11/dist-packages (from mkdocs-material>=9.5.49->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (0.4.6)
# Requirement already satisfied: mkdocs-material-extensions~=1.3 in /usr/local/lib/python3.11/dist-packages (from mkdocs-material>=9.5.49->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (1.3.1)
# Requirement already satisfied: paginate~=0.5 in /usr/local/lib/python3.11/dist-packages (from mkdocs-material>=9.5.49->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (0.5.7)
# Requirement already satisfied: pymdown-extensions~=10.2 in /usr/local/lib/python3.11/dist-packages (from mkdocs-material>=9.5.49->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (10.16)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.70.0->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.70.0->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (1.3.1)
# Requirement already satisfied: cfgv>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pre-commit>=4.2.0->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from pre-commit>=4.2.0->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (2.6.12)
# Requirement already satisfied: nodeenv>=0.11.1 in /usr/local/lib/python3.11/dist-packages (from pre-commit>=4.2.0->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (1.9.1)
# Requirement already satisfied: virtualenv>=20.10.0 in /usr/local/lib/python3.11/dist-packages (from pre-commit>=4.2.0->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (20.31.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (2.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (2025.4.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (0.25.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (2025.2)
# Requirement already satisfied: platformdirs>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from mkdocs-get-deps>=0.2.0->mkdocs>=1.6.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (4.3.8)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (1.17.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.11/dist-packages (from virtualenv>=20.10.0->pre-commit>=4.2.0->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (0.3.9)

# %% [markdown]
# ## Start synthesizing
#
# As we've seen in the previous course content, we can create a distilabel pipelines for instruction dataset generation. The bare minimum pipline is already provided. Make sure to scale up this pipeline to generate a large dataset for instruction tuning. Swap out models, model providers and generation arguments to see how they affect the quality of the dataset. Experiment small, scale up later.
#
# Check out the [distilabel components gallery](https://distilabel.argilla.io/latest/components-gallery/) for information about the processing classes and how to use them.
#
# An example of loading data from the Hub instead of dictionaries is provided below.
#
# ```python
# from datasets import load_dataset
#
# with Pipeline(...) as pipeline:
#     ...
#
# if __name__ == "__main__:
#     dataset = load_dataset("my-dataset", split="train")
#     distiset = pipeline.run(dataset=dataset)
# ```
#
# Don't forget to push your dataset to the Hub after running the pipeline!

# %%
from distilabel.llms import TransformersLLM
from distilabel.pipeline import Pipeline
from distilabel.steps import LoadDataFromDicts
from distilabel.steps.tasks import TextGeneration

with Pipeline() as pipeline:
    data = LoadDataFromDicts(data=[{"instruction": "Generate a short question about the Hugging Face Smol-Course."}])
    llm = TransformersLLM(model="HuggingFaceTB/SmolLM2-1.7B-Instruct")
    gen_a = TextGeneration(llm=llm, output_mappings={"generation": "instruction"})
    gen_b = TextGeneration(llm=llm, output_mappings={"generation": "response"})
    data >> gen_a >> gen_b

if __name__ == "__main__":
    distiset = pipeline.run(use_cache=False)
    distiset.push_to_hub("huggingface-smol-course-instruction-tuning-dataset")
# Out:
# /tmp/ipython-input-2-3942041254.py:1: DeprecationWarning: Importing from 'distilabel.llms' is deprecated and will be removed in a version 1.7.0. Import from 'distilabel.models' instead.
#   from distilabel.llms import TransformersLLM
# [06/28/25 15:28:39] INFO     ['distilabel.pipeline'] 📝 Pipeline data will be written to               ]8;id=42258;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=880338;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/base.py#1015\1015]8;;\
#                              '/root/.cache/distilabel/pipelines/pipeline_load_data_from_dicts_0_text_g
#                              eneration_0_text_generation_1/c01ebfb0c402b5259a883a99a288ac77e435bd20/ex
#                              ecutions/ba93fee5474d2e343a10a1c4b6e96bcada7c66a6/data/steps_outputs'
#                     INFO     ['distilabel.pipeline'] ⌛ The steps of the pipeline will be loaded in    ]8;id=657329;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=852557;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/base.py#1046\1046]8;;\
#                              stages:
#                               * Legend: 🚰 GeneratorStep 🌐 GlobalStep 🔄 Step
#                               * Stage 0:
#                                 - 🚰 'load_data_from_dicts_0'
#                                 - 🔄 'text_generation_0'
#                                 - 🔄 'text_generation_1'
#                     INFO     ['distilabel.pipeline'] ⏳ Waiting for all the steps of stage 0 to        ]8;id=365856;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=2241;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/base.py#1382\1382]8;;\
#                              load...
# [06/28/25 15:28:42] INFO     ['distilabel.pipeline'] ⏳ Steps from stage 0 loaded: 1/3                 ]8;id=737146;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=497729;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/base.py#1418\1418]8;;\
#                               * 'load_data_from_dicts_0' replicas: 1/1
#                               * 'text_generation_0' replicas: 0/1
#                               * 'text_generation_1' replicas: 0/1
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# Device set to use cuda:0
# Device set to use cuda:0
# [06/28/25 15:29:02] INFO     ['distilabel.pipeline'] ⏳ Steps from stage 0 loaded: 3/3                 ]8;id=189319;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=379477;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/base.py#1418\1418]8;;\
#                               * 'load_data_from_dicts_0' replicas: 1/1
#                               * 'text_generation_0' replicas: 1/1
#                               * 'text_generation_1' replicas: 1/1
#                     INFO     ['distilabel.pipeline'] ✅ All the steps from stage 0 have been loaded!   ]8;id=747476;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=853852;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/base.py#1422\1422]8;;\
#                     INFO     ['distilabel.step.load_data_from_dicts_0'] 🚰 Starting yielding    ]8;id=61924;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=219103;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/step_wrapper.py#179\179]8;;\
#                              batches from generator step 'load_data_from_dicts_0'. Offset: 0
#                     INFO     ['distilabel.step.load_data_from_dicts_0'] 📨 Step                 ]8;id=995757;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=979196;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/step_wrapper.py#290\290]8;;\
#                              'load_data_from_dicts_0' sending batch 0 to output queue
#                     INFO     ['distilabel.step.load_data_from_dicts_0'] 🏁 Finished running     ]8;id=503294;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=56858;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/step_wrapper.py#129\129]8;;\
#                              step 'load_data_from_dicts_0' (replica ID: 0)
#                     INFO     ['distilabel.step.text_generation_0'] 📦 Processing batch 0 in     ]8;id=64068;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=642356;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/step_wrapper.py#230\230]8;;\
#                              'text_generation_0' (replica ID: 0)
# [06/28/25 15:29:03] INFO     ['distilabel.step.text_generation_0'] 📨 Step 'text_generation_0'  ]8;id=871673;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=352234;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/step_wrapper.py#290\290]8;;\
#                              sending batch 0 to output queue
#                     INFO     ['distilabel.step.text_generation_0'] 🏁 Finished running step     ]8;id=988753;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=900770;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/step_wrapper.py#129\129]8;;\
#                              'text_generation_0' (replica ID: 0)
#                     INFO     ['distilabel.step.text_generation_1'] 📦 Processing batch 0 in     ]8;id=571526;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=957261;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/step_wrapper.py#230\230]8;;\
#                              'text_generation_1' (replica ID: 0)
# [06/28/25 15:29:06] INFO     ['distilabel.step.text_generation_1'] 📨 Step 'text_generation_1'  ]8;id=927954;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=38222;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/step_wrapper.py#290\290]8;;\
#                              sending batch 0 to output queue
#                     INFO     ['distilabel.step.text_generation_1'] 🏁 Finished running step     ]8;id=548870;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=273711;file:///usr/local/lib/python3.11/dist-packages/distilabel/pipeline/step_wrapper.py#129\129]8;;\
#                              'text_generation_1' (replica ID: 0)
# Generating train split: 0 examples [00:00, ? examples/s]
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 0>:15                                                                             │
# │                                                                                                  │
# │   12                                                                                             │
# │   13 if __name__ == "__main__":                                                                  │
# │   14 │   distiset = pipeline.run(use_cache=False)                                                │
# │ ❱ 15 │   distiset.push_to_hub("huggingface-smol-course-instruction-tuning-dataset")              │
# │   16                                                                                             │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │        data = LoadDataFromDicts(                                                             │ │
# │ │               │   exclude_from_signature={                                                   │ │
# │ │               │   │   'llm_offline_batch_generation_block_until_done',                       │ │
# │ │               │   │   'exclude_from_signature',                                              │ │
# │ │               │   │   'resources',                                                           │ │
# │ │               │   │   'input_batch_size',                                                    │ │
# │ │               │   │   'gpu_memory_utilization',                                              │ │
# │ │               │   │   'llm_jobs_ids',                                                        │ │
# │ │               │   │   'type_info',                                                           │ │
# │ │               │   │   'disable_cuda_device_placement'                                        │ │
# │ │               │   },                                                                         │ │
# │ │               │   name='load_data_from_dicts_0',                                             │ │
# │ │               │   resources=StepResources(                                                   │ │
# │ │               │   │   replicas=1,                                                            │ │
# │ │               │   │   cpus=None,                                                             │ │
# │ │               │   │   gpus=None,                                                             │ │
# │ │               │   │   memory=None,                                                           │ │
# │ │               │   │   resources=None                                                         │ │
# │ │               │   ),                                                                         │ │
# │ │               │   input_mappings={},                                                         │ │
# │ │               │   output_mappings={},                                                        │ │
# │ │               │   use_cache=True,                                                            │ │
# │ │               │   batch_size=50,                                                             │ │
# │ │               │   data=[                                                                     │ │
# │ │               │   │   {                                                                      │ │
# │ │               │   │   │   'instruction': 'Generate a short question about the Hugging Face   │ │
# │ │               Smol-Course.'                                                                  │ │
# │ │               │   │   }                                                                      │ │
# │ │               │   ]                                                                          │ │
# │ │               )                                                                              │ │
# │ │    distiset = Distiset({                                                                     │ │
# │ │               │   default: DatasetDict({                                                     │ │
# │ │               │   │   train: Dataset({                                                       │ │
# │ │               │   │   │   features: ['instruction', 'distilabel_metadata', 'model_name',     │ │
# │ │               'response'],                                                                   │ │
# │ │               │   │   │   num_rows: 1                                                        │ │
# │ │               │   │   })                                                                     │ │
# │ │               │   })                                                                         │ │
# │ │               })                                                                             │ │
# │ │        exit = <IPython.core.autocall.ZMQExitAutocall object at 0x7ca70603a690>               │ │
# │ │       gen_a = TextGeneration(                                                                │ │
# │ │               │   exclude_from_signature={                                                   │ │
# │ │               │   │   'llm_offline_batch_generation_block_until_done',                       │ │
# │ │               │   │   'exclude_from_signature',                                              │ │
# │ │               │   │   'resources',                                                           │ │
# │ │               │   │   'input_batch_size',                                                    │ │
# │ │               │   │   'gpu_memory_utilization',                                              │ │
# │ │               │   │   'llm_jobs_ids',                                                        │ │
# │ │               │   │   'type_info',                                                           │ │
# │ │               │   │   'disable_cuda_device_placement'                                        │ │
# │ │               │   },                                                                         │ │
# │ │               │   name='text_generation_0',                                                  │ │
# │ │               │   resources=StepResources(                                                   │ │
# │ │               │   │   replicas=1,                                                            │ │
# │ │               │   │   cpus=None,                                                             │ │
# │ │               │   │   gpus=None,                                                             │ │
# │ │               │   │   memory=None,                                                           │ │
# │ │               │   │   resources=None                                                         │ │
# │ │               │   ),                                                                         │ │
# │ │               │   input_mappings={},                                                         │ │
# │ │               │   output_mappings={'generation': 'instruction'},                             │ │
# │ │               │   use_cache=True,                                                            │ │
# │ │               │   input_batch_size=50,                                                       │ │
# │ │               │   llm=TransformersLLM(                                                       │ │
# │ │               │   │   cuda_devices='auto',                                                   │ │
# │ │               │   │   disable_cuda_device_placement=False,                                   │ │
# │ │               │   │   use_magpie_template=False,                                             │ │
# │ │               │   │   magpie_pre_query_template=None,                                        │ │
# │ │               │   │   generation_kwargs={},                                                  │ │
# │ │               │   │   use_offline_batch_generation=False,                                    │ │
# │ │               │   │   offline_batch_generation_block_until_done=None,                        │ │
# │ │               │   │   jobs_ids=None,                                                         │ │
# │ │               │   │   model='HuggingFaceTB/SmolLM2-1.7B-Instruct',                           │ │
# │ │               │   │   revision='main',                                                       │ │
# │ │               │   │   torch_dtype='auto',                                                    │ │
# │ │               │   │   trust_remote_code=False,                                               │ │
# │ │               │   │   model_kwargs=None,                                                     │ │
# │ │               │   │   tokenizer=None,                                                        │ │
# │ │               │   │   use_fast=True,                                                         │ │
# │ │               │   │   chat_template=None,                                                    │ │
# │ │               │   │   device=None,                                                           │ │
# │ │               │   │   device_map=None,                                                       │ │
# │ │               │   │   token=None,                                                            │ │
# │ │               │   │   structured_output=None                                                 │ │
# │ │               │   ),                                                                         │ │
# │ │               │   group_generations=False,                                                   │ │
# │ │               │   add_raw_output=True,                                                       │ │
# │ │               │   add_raw_input=True,                                                        │ │
# │ │               │   num_generations=1,                                                         │ │
# │ │               │   use_default_structured_output=False,                                       │ │
# │ │               │   system_prompt=None,                                                        │ │
# │ │               │   use_system_prompt=True,                                                    │ │
# │ │               │   template='{{ instruction }}',                                              │ │
# │ │               │   columns=['instruction']                                                    │ │
# │ │               )                                                                              │ │
# │ │       gen_b = TextGeneration(                                                                │ │
# │ │               │   exclude_from_signature={                                                   │ │
# │ │               │   │   'llm_offline_batch_generation_block_until_done',                       │ │
# │ │               │   │   'exclude_from_signature',                                              │ │
# │ │               │   │   'resources',                                                           │ │
# │ │               │   │   'input_batch_size',                                                    │ │
# │ │               │   │   'gpu_memory_utilization',                                              │ │
# │ │               │   │   'llm_jobs_ids',                                                        │ │
# │ │               │   │   'type_info',                                                           │ │
# │ │               │   │   'disable_cuda_device_placement'                                        │ │
# │ │               │   },                                                                         │ │
# │ │               │   name='text_generation_1',                                                  │ │
# │ │               │   resources=StepResources(                                                   │ │
# │ │               │   │   replicas=1,                                                            │ │
# │ │               │   │   cpus=None,                                                             │ │
# │ │               │   │   gpus=None,                                                             │ │
# │ │               │   │   memory=None,                                                           │ │
# │ │               │   │   resources=None                                                         │ │
# │ │               │   ),                                                                         │ │
# │ │               │   input_mappings={},                                                         │ │
# │ │               │   output_mappings={'generation': 'response'},                                │ │
# │ │               │   use_cache=True,                                                            │ │
# │ │               │   input_batch_size=50,                                                       │ │
# │ │               │   llm=TransformersLLM(                                                       │ │
# │ │               │   │   cuda_devices='auto',                                                   │ │
# │ │               │   │   disable_cuda_device_placement=False,                                   │ │
# │ │               │   │   use_magpie_template=False,                                             │ │
# │ │               │   │   magpie_pre_query_template=None,                                        │ │
# │ │               │   │   generation_kwargs={},                                                  │ │
# │ │               │   │   use_offline_batch_generation=False,                                    │ │
# │ │               │   │   offline_batch_generation_block_until_done=None,                        │ │
# │ │               │   │   jobs_ids=None,                                                         │ │
# │ │               │   │   model='HuggingFaceTB/SmolLM2-1.7B-Instruct',                           │ │
# │ │               │   │   revision='main',                                                       │ │
# │ │               │   │   torch_dtype='auto',                                                    │ │
# │ │               │   │   trust_remote_code=False,                                               │ │
# │ │               │   │   model_kwargs=None,                                                     │ │
# │ │               │   │   tokenizer=None,                                                        │ │
# │ │               │   │   use_fast=True,                                                         │ │
# │ │               │   │   chat_template=None,                                                    │ │
# │ │               │   │   device=None,                                                           │ │
# │ │               │   │   device_map=None,                                                       │ │
# │ │               │   │   token=None,                                                            │ │
# │ │               │   │   structured_output=None                                                 │ │
# │ │               │   ),                                                                         │ │
# │ │               │   group_generations=False,                                                   │ │
# │ │               │   add_raw_output=True,                                                       │ │
# │ │               │   add_raw_input=True,                                                        │ │
# │ │               │   num_generations=1,                                                         │ │
# │ │               │   use_default_structured_output=False,                                       │ │
# │ │               │   system_prompt=None,                                                        │ │
# │ │               │   use_system_prompt=True,                                                    │ │
# │ │               │   template='{{ instruction }}',                                              │ │
# │ │               │   columns=['instruction']                                                    │ │
# │ │               )                                                                              │ │
# │ │ get_ipython = <bound method InteractiveShell.get_ipython of <google.colab._shell.Shell       │ │
# │ │               object at 0x7ca70602b0d0>>                                                     │ │
# │ │          In = [                                                                              │ │
# │ │               │   '',                                                                        │ │
# │ │               │   'get_ipython().system(\'pip install                                        │ │
# │ │               "distilabel[hf-transformers,outlines,instructo'+5,                             │ │
# │ │               │   'from distilabel.llms import TransformersLLM\nfrom distilabel.pipeline     │ │
# │ │               import Pipe'+662                                                               │ │
# │ │               ]                                                                              │ │
# │ │         llm = TransformersLLM(                                                               │ │
# │ │               │   cuda_devices='auto',                                                       │ │
# │ │               │   disable_cuda_device_placement=False,                                       │ │
# │ │               │   use_magpie_template=False,                                                 │ │
# │ │               │   magpie_pre_query_template=None,                                            │ │
# │ │               │   generation_kwargs={},                                                      │ │
# │ │               │   use_offline_batch_generation=False,                                        │ │
# │ │               │   offline_batch_generation_block_until_done=None,                            │ │
# │ │               │   jobs_ids=None,                                                             │ │
# │ │               │   model='HuggingFaceTB/SmolLM2-1.7B-Instruct',                               │ │
# │ │               │   revision='main',                                                           │ │
# │ │               │   torch_dtype='auto',                                                        │ │
# │ │               │   trust_remote_code=False,                                                   │ │
# │ │               │   model_kwargs=None,                                                         │ │
# │ │               │   tokenizer=None,                                                            │ │
# │ │               │   use_fast=True,                                                             │ │
# │ │               │   chat_template=None,                                                        │ │
# │ │               │   device=None,                                                               │ │
# │ │               │   device_map=None,                                                           │ │
# │ │               │   token=None,                                                                │ │
# │ │               │   structured_output=None                                                     │ │
# │ │               )                                                                              │ │
# │ │         Out = {}                                                                             │ │
# │ │    pipeline = <distilabel.pipeline.local.Pipeline object at 0x7ca6b93a8f50>                  │ │
# │ │        quit = <IPython.core.autocall.ZMQExitAutocall object at 0x7ca70603a690>               │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /usr/local/lib/python3.11/dist-packages/distilabel/distiset.py:138 in push_to_hub                │
# │                                                                                                  │
# │   135 │   │   script_path = Path.cwd() / script_filename                                         │
# │   136 │   │                                                                                      │
# │   137 │   │   if token is None:                                                                  │
# │ ❱ 138 │   │   │   token = get_hf_token(self.__class__.__name__, "token")                         │
# │   139 │   │                                                                                      │
# │   140 │   │   for name, dataset in self.items():                                                 │
# │   141 │   │   │   dataset.push_to_hub(                                                           │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │     filename_py = 'colab_kernel_launcher.py'                                                 │ │
# │ │   generate_card = True                                                                       │ │
# │ │  include_script = False                                                                      │ │
# │ │          kwargs = {}                                                                         │ │
# │ │         private = False                                                                      │ │
# │ │         repo_id = 'huggingface-smol-course-instruction-tuning-dataset'                       │ │
# │ │ script_filename = '/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py'         │ │
# │ │     script_path = PosixPath('/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.… │ │
# │ │            self = Distiset({                                                                 │ │
# │ │                   │   default: DatasetDict({                                                 │ │
# │ │                   │   │   train: Dataset({                                                   │ │
# │ │                   │   │   │   features: ['instruction', 'distilabel_metadata', 'model_name', │ │
# │ │                   'response'],                                                               │ │
# │ │                   │   │   │   num_rows: 1                                                    │ │
# │ │                   │   │   })                                                                 │ │
# │ │                   │   })                                                                     │ │
# │ │                   })                                                                         │ │
# │ │           token = None                                                                       │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /usr/local/lib/python3.11/dist-packages/distilabel/utils/huggingface.py:45 in get_hf_token       │
# │                                                                                                  │
# │   42 │   token = os.getenv(HF_TOKEN_ENV_VAR)                                                     │
# │   43 │   if token is None:                                                                       │
# │   44 │   │   if not Path(constants.HF_TOKEN_PATH).exists():                                      │
# │ ❱ 45 │   │   │   raise ValueError(                                                               │
# │   46 │   │   │   │   f"To use `{cls_name}` an API key must be provided via `{token_arg}`,"       │
# │   47 │   │   │   │   f" set the environment variable `{HF_TOKEN_ENV_VAR}` or use the"            │
# │   48 │   │   │   │   " `huggingface-hub` CLI to login with `huggingface-cli login`."             │
# │                                                                                                  │
# │ ╭──────── locals ────────╮                                                                       │
# │ │  cls_name = 'Distiset' │                                                                       │
# │ │     token = None       │                                                                       │
# │ │ token_arg = 'token'    │                                                                       │
# │ ╰────────────────────────╯                                                                       │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: To use `Distiset` an API key must be provided via `token`, set the environment variable `HF_TOKEN` or
# use the `huggingface-hub` CLI to login with `huggingface-cli login`.

# %% [markdown]
# ## 🌯 That's a wrap
#
# You've now seen how to generate a dataset for instruction tuning. You could use this to:
#
# - Generate a dataset for instruction tuning.
# - Create evaluation datasets for instruction tuning.
#
# Next
#
# 🧑‍🏫 Learn - About [generating preference datasets](./preference_datasets.md)
# 🏋️‍♂️ Fine-tune a model for instruction tuning with a synthetic dataset based on the [instruction tuning chapter](../../1_instruction_tuning/README.md)
